# %%
import pandas as pd
import numpy as np

# %%
d=pd.read_csv('cleaned_data.csv')

# %%
d.head()
# Out:
#    Unnamed: 0        id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0           0    842302         M        17.99         10.38          122.80
# 1           1    842517         M        20.57         17.77          132.90
# 2           2  84300903         M        19.69         21.25          130.00
# 3           3  84348301         M        11.42         20.38           77.58
# 4           4  84358402         M        20.29         14.34          135.10
#
#    area_mean  smoothness_mean  compactness_mean  concavity_mean  ...  \
# 0     1001.0          0.11840           0.27760          0.3001  ...
# 1     1326.0          0.08474           0.07864          0.0869  ...
# 2     1203.0          0.10960           0.15990          0.1974  ...
# 3      386.1          0.14250           0.28390          0.2414  ...
# 4     1297.0          0.10030           0.13280          0.1980  ...
#
#    radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# ...

# %%
del d['Unnamed: 0']

# %%
d.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
pd.cut(d['radius_mean'],bins=4)

# %%
labels_radius_mean = ['(6.96, 12.263]','(12.263, 17.545]','(17.545, 22.828]','(22.828, 28.11]']

# %%
d['radius_mean_labels']=pd.cut(d['radius_mean'],bins=4,labels=labels_radius_mean)

# %%
d.head()

# %%
pd.cut(d['texture_mean'],bins=4)

# %%
labels_texture_mean = ['(9.68, 17.102]','(17.102, 24.495]','(24.495, 31.888]','(31.888, 39.28]']

# %%
d['texture_mean_labels']=pd.cut(d['texture_mean'],bins=4,labels=labels_texture_mean)

# %%
pd.cut(d['perimeter_mean'],bins=4)

# %%
labels_perimeter_mean = ['(43.645, 79.968]','(79.968, 116.145]','(116.145, 152.322]','(152.322, 188.5]']

# %%
d['perimeter_mean_labels']=pd.cut(d['perimeter_mean'],bins=4,labels=labels_perimeter_mean)

# %%
d.head()
# Out:
#          id diagnosis  perimeter_mean  area_mean  smoothness_mean  \
# 0    842302         M          122.80     1001.0          0.11840
# 1    842517         M          132.90     1326.0          0.08474
# 2  84300903         M          130.00     1203.0          0.10960
# 3  84348301         M           77.58      386.1          0.14250
# 4  84358402         M          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
d.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
def data_descritization(d):
        l = d.columns
        for s in l:
            print(type(s))
            print(s)
            if (s=='id' or s=='diagnosis'):
                continue;
            else:
                s1=s+"_labels"
                print(s1)
                print(type(s1))
                d[s1]=pd.cut(d[s],bins=5,labels=[0 , 1 , 2 , 3 , 4])
                del d[s]

                
                
data_descritization(d)
print(d)
# Out:
# <class 'str'>
# id
# <class 'str'>
# diagnosis
# <class 'str'>
# radius_mean
# radius_mean_labels
# <class 'str'>
# <class 'str'>
# texture_mean
# texture_mean_labels
# <class 'str'>
# <class 'str'>
# perimeter_mean
# perimeter_mean_labels
# <class 'str'>
# <class 'str'>
# area_mean
# area_mean_labels
# <class 'str'>
# <class 'str'>
# smoothness_mean
# smoothness_mean_labels
# <class 'str'>
# <class 'str'>
# compactness_mean
# compactness_mean_labels
# <class 'str'>
# <class 'str'>
# concavity_mean
# concavity_mean_labels
# <class 'str'>
# <class 'str'>
# concave points_mean
# concave points_mean_labels
# <class 'str'>
# <class 'str'>
# symmetry_mean
# symmetry_mean_labels
# <class 'str'>
# <class 'str'>
# fractal_dimension_mean
# fractal_dimension_mean_labels
# <class 'str'>
# <class 'str'>
# radius_se
# radius_se_labels
# <class 'str'>
# <class 'str'>
# texture_se
# texture_se_labels
# <class 'str'>
# <class 'str'>
# perimeter_se
# perimeter_se_labels
# <class 'str'>
# ...

# %%
d.to_csv("labelled_data.csv")
